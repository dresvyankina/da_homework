# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/da-python/python-for-data-analytics/blob/main/Lesson1/hometask/without_pandas.ipynb)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('lyDLAutA88s', width=800, height=300)

# %%
# Colab Version
# !pip install wget
# !mkdir data
# !wget https://raw.githubusercontent.com/da-python/python-for-data-analytics/main/Lesson1/hometask/vacancy.csv.zip

# %%
import csv
import sys, codecs
from collections import Counter, defaultdict

# %%
csv.field_size_limit()
# Out:
# 131072

# %%
#увеличиваем лимит (1 способ)
csv.field_size_limit(10000000)
# Out:
# 131072

# %%
#увеличиваем лимит (2 способ)
maxInt = sys.maxsize

while True:
    # decrease the maxInt value by factor 10 
    # as long as the OverflowError occurs.

    try:
        csv.field_size_limit(maxInt)
        break
    except OverflowError:
        maxInt = int(maxInt/10)

# %%
csv.field_size_limit()
# Out:
# 922337203

# %%
import shutil

# %%
#import codecs
#file = codecs.open( "vacancy.csv", "r", "utf-8" )
#data = file.read()

# %%
vacs = list(csv.DictReader(open('vacancy.csv', encoding="utf-8")))

# %%
len(vacs)
# Out:
# 4002

# %%
vacs[0]
# Out:
# {'id': '383479',
#  'created_at': '2021-03-14 09:39:21.854462',
#  'updated_at': '2021-03-14 09:39:21.854584',
#  'vacid': '1474941',
#  'vactitle': 'Senior java-разработчик (в команду Онбординга)',
# ...

# %%
vacs[-1]
# Out:
# {'id': '383478',
#  'created_at': '2021-03-14 09:39:21.854462',
#  'updated_at': '2021-03-14 09:39:21.854584',
#  'vacid': '1474689',
#  'vactitle': 'Мобильный менеджер по продажам со знанием таджикского/узбекского/кыргызского языков',
# ...

# %%
{row ['vactitle'] for row in vacs}
# Out:
# {'Руководитель контент-группы',
#  'Менеджер по продажам с. Старосубхангулово',
#  'Fullstack-разработчик',
#  'Системный аналитик ( ЦКР)',
#  'ABAP разработчик под АСУС EWM',
#  'Системный аналитик (Криптосервисы)',
#  'Менеджер проекта (IT Bootcamp Сбера)',
#  'Главный клиентский менеджер TechSales',
#  'QA (нагрузочное тестирование)',
#  'Архитектор (Комплаенс)',
#  'Бизнес-аналитик в команду «Payments.Юпитер»',
#  'Ведущий инженер по автоматизированному тестированию',
#  'Главный инженер по разработке/ Разработчик бизнес-процессов',
#  'Специалист управления безопасности',
#  'Администратор \xa0сопровождения тестовых и промышленных стендов',
#  'FullStack разработчик',
#  'Android разработчик, SberDevices',
#  'Data Scientist at Sber Corporate (Управление продажами в Субъектах РФ)',
#  'QA',
#  'QA engineer (беспилотник)',
#  'Эксперт по операциям на финансовых рынках (Управление Рисков)',
#  'Ведущий инженер',
# ...

# %%
analytic_data = [row for row in vacs if row ['vactitle'] == 'Аналитик данных']

# %%
# Сколько вакансий, которые вам нравятся?

# %%
len(analytic_data)
# Out:
# 5

# %%
analytic_data[0]
# Out:
# {'id': '384059',
#  'created_at': '2021-03-14 09:39:21.854462',
#  'updated_at': '2021-03-14 09:39:21.854584',
#  'vacid': '1564018',
#  'vactitle': 'Аналитик данных',
# ...

# %%
# За какие периоды эти вакансии?

# %%
data = Counter(row['created_at'][0:10] for row in vacs)

# %%
data.most_common()
# Out:
# [('2021-03-14', 4002)]

# %%
# Сколько вакансий с такими позициями, на которых вы работаете?

# %%
c = Counter(row ['vactitle'] for row in vacs)

# %%
c.get('Специалист')
# Out:
# 17

# %%
# Сколько вакансий для аналитика данных?

# %%
fail = [row for row in vacs if row ['vactitle'] == 'Аналитик данных' if row ['vactitle'] =='Data Analyst']

# %%
c = Counter(row ['vactitle'] for row in vacs)

# %%
c.most_common()
# Out:
# [('Мобильный менеджер по продажам', 229),
#  ('Старший менеджер по обслуживанию', 172),
#  ('Специалист по прямым продажам', 164),
#  ('Менеджер по продажам', 86),
#  ('Системный аналитик', 62),
#  ('Менеджер по работе с ключевыми клиентами малого бизнеса', 53),
#  ('Java разработчик', 40),
#  ('Водитель-инкассатор', 38),
#  ('Старший специалист по взысканию задолженности', 38),
#  ('Главный клиентский менеджер малого бизнеса', 34),
#  ('Главный инженер по разработке', 25),
#  ('Менеджер по продаже зарплатных проектов', 25),
#  ('Java-разработчик', 24),
#  ('Ведущий инженер по сопровождению', 22),
#  ('Практикант', 22),
#  ('Ведущий специалист по взысканию', 21),
#  ('Менеджер по продажам продуктов канала', 20),
#  ('DevOps инженер', 20),
#  ('Старший инженер', 18),
#  ('Ведущий специалист судебного и исполнительного производства', 18),
#  ('Ведущий специалист по взысканию задолженности', 18),
#  ('Клиентский менеджер Сбербанк Премьер', 18),
#  ('Ведущий инженер по разработке', 17),
# ...

# %%
cs = sorted(c.most_common(), key=lambda x:x[1], reverse=True)

# %%
from collections import defaultdict

d = defaultdict(list)
for k, v in cs:
    d[k].append(v)

sorted(d.items())
# Out:
# [('<p>Ведущий аналитик</p>', [1]),
#  ('ABAP разработчик', [2]),
#  ('ABAP разработчик под АСУС EWM', [1]),
#  ('Administrator Linux/DevOps', [1]),
#  ('Agile coach', [1]),
#  ('Analyst (Аналитик, команда Клиентской аналитики, Корп.блок)', [1]),
#  ('Analyst / Associate в Change подразделении Департамента Инвестиционной деятельности',
#   [1]),
#  ('Analyst International project in the UAE', [1]),
#  ('Andorid-разработчик', [1]),
#  ('Android developer', [1]),
#  ('Android разработчик', [2]),
#  ('Android разработчик (Private Banking)', [1]),
#  ('Android разработчик (Sber911)', [1]),
#  ('Android разработчик, SberDevices', [1]),
#  ('Android-developer', [1]),
#  ('Android-разработчик', [1]),
#  ('Android-разработчик (Сервисы ʺПлати QRʺ)', [1]),
#  ('Automation QA Engineer (TagMe)', [1]),
#  ('Back-end разработчик', [1]),
#  ('Back-end разработчик (Java)', [1]),
#  ('Back-end разработчик (Java/Spring)', [1]),
#  ('Back-end разработчик (Python)', [1]),
# ...

# %%
d
# Out:
# defaultdict(list,
#             {'Мобильный менеджер по продажам': [229],
#              'Старший менеджер по обслуживанию': [172],
#              'Специалист по прямым продажам': [164],
#              'Менеджер по продажам': [86],
#              'Системный аналитик': [62],
#              'Менеджер по работе с ключевыми клиентами малого бизнеса': [53],
#              'Java разработчик': [40],
#              'Водитель-инкассатор': [38],
#              'Старший специалист по взысканию задолженности': [38],
#              'Главный клиентский менеджер малого бизнеса': [34],
#              'Главный инженер по разработке': [25],
#              'Менеджер по продаже зарплатных проектов': [25],
#              'Java-разработчик': [24],
#              'Ведущий инженер по сопровождению': [22],
#              'Практикант': [22],
#              'Ведущий специалист по взысканию': [21],
#              'Менеджер по продажам продуктов канала': [20],
#              'DevOps инженер': [20],
# ...

# %%
vv = Counter(row ['vactitle'] for row in vacs if row ['vactitle'] == 'Аналитик данных' or row ['vactitle'] == 'Data Analyst')

# %%
vv.most_common()
# Out:
# [('Аналитик данных', 5), ('Data Analyst', 3)]

# %%
value_counts = Counter(d)
zzz = value_counts.most_common()

# %%
zzz
# Out:
# [('Мобильный менеджер по продажам', [229]),
#  ('Старший менеджер по обслуживанию', [172]),
#  ('Специалист по прямым продажам', [164]),
#  ('Менеджер по продажам', [86]),
#  ('Системный аналитик', [62]),
#  ('Менеджер по работе с ключевыми клиентами малого бизнеса', [53]),
#  ('Java разработчик', [40]),
#  ('Водитель-инкассатор', [38]),
#  ('Старший специалист по взысканию задолженности', [38]),
#  ('Главный клиентский менеджер малого бизнеса', [34]),
#  ('Главный инженер по разработке', [25]),
#  ('Менеджер по продаже зарплатных проектов', [25]),
#  ('Java-разработчик', [24]),
#  ('Ведущий инженер по сопровождению', [22]),
#  ('Практикант', [22]),
#  ('Ведущий специалист по взысканию', [21]),
#  ('Менеджер по продажам продуктов канала', [20]),
#  ('DevOps инженер', [20]),
#  ('Старший инженер', [18]),
#  ('Ведущий специалист судебного и исполнительного производства', [18]),
#  ('Ведущий специалист по взысканию задолженности', [18]),
# ...

# %%
#Сколько вакансий для аналитика данных с использованием Python

# %%
words = {'Python'}
for row in vv:
    if words & set(row):
        d[words].append(row)

# %%
row = row['vacdescription']

# %%
row
# Out:
# 'Мы предлагаем: - оформление согласно трудовому кодексу РФ;- оклад плюс система премий по результатам работы (ежемесячная и годовая премии);- ДМС и материальная поддержка;- корпоративное обучение;- профессиональный и карьерный рост;- яркая и насыщенная корпоративная жизнь (праздники, соревнования, спортивные мероприятия);- скидки на продукты Сбербанка и экосистемы. Работая в Сбербанке, ты меняешь жизнь людей вокруг себя к лучшему! Интересна вакансия? - жми «откликнуться»;- запиши видеоинтервью по ссылке из смс или письма с любого удобного устройства;- пройди собеседование с руководителем. Мы ждем тебя, чтобы строить счастливое будущее вместе! Контактная информацияКоманда подбора персонала Сбербанка+7 (495) 742-60-50от 73 000 руб. до вычета налогов Задача мобильного менеджера ― продавать продукты Сбербанка через планшет и терминалы самообслуживания. Эта должность подойдет тем, кто готов к работе на «ногах», открыт к новому и нацелен на развитие в продажах.Если хочешь овладеть навыком 
# ...

# %%
import re
n_row = re.split(" |!|'+'|;|:|,", (row))

# %%
n_row
# Out:
# ['Мы',
#  'предлагаем',
#  '',
#  '-',
#  'оформление',
#  'согласно',
#  'трудовому',
#  'кодексу',
#  'РФ',
#  '-',
#  'оклад',
#  'плюс',
#  'система',
#  'премий',
#  'по',
#  'результатам',
#  'работы',
#  '(ежемесячная',
#  'и',
#  'годовая',
#  'премии)',
#  '-',
#  'ДМС',
#  'и',
#  'материальная',
#  'поддержка',
#  '-',
#  'корпоративное',
#  'обучение',
#  '-',
#  'профессиональный',
#  'и',
#  'карьерный',
#  'рост',
#  '-',
#  'яркая',
#  'и',
#  'насыщенная',
#  'корпоративная',
#  'жизнь',
#  '(праздники',
#  '',
#  'соревнования',
#  '',
#  'спортивные',
#  'мероприятия)',
#  '-',
#  'скидки',
#  'на',
#  'продукты',
#  'Сбербанка',
#  'и',
#  'экосистемы.',
#  'Работая',
#  'в',
#  'Сбербанке',
#  '',
#  'ты',
#  'меняешь',
#  'жизнь',
#  'людей',
#  'вокруг',
#  'себя',
#  'к',
#  'лучшему',
#  '',
#  'Интересна',
#  'вакансия?',
#  '-',
#  'жми',
#  '«откликнуться»',
#  '-',
#  'запиши',
#  'видеоинтервью',
#  'по',
#  'ссылке',
#  'из',
#  'смс',
#  'или',
# ...

# %%
vvp= Counter(row ['vactitle'] for row in n_row if (row ['vactitle'] == 'Аналитик данных') and (row['vacdescription'].split(' '/'.'/'+') == 'Python'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-92-fc98b9edbc77> in <module>
# ----> 1 vvp= Counter(row ['vactitle'] for row in n_row if (row ['vactitle'] == 'Аналитик данных') and (row['vacdescription'].split(' '/'.'/'+') == 'Python'))
#
# ~\anaconda3\lib\collections\__init__.py in __init__(self, iterable, **kwds)
#     550         '''
#     551         super(Counter, self).__init__()
# --> 552         self.update(iterable, **kwds)
#     553
#     554     def __missing__(self, key):
#
# ~\anaconda3\lib\collections\__init__.py in update(self, iterable, **kwds)
#     635                     super(Counter, self).update(iterable) # fast path when counter is empty
#     636             else:
# --> 637                 _count_elements(self, iterable)
#     638         if kwds:
#     639             self.update(kwds)
#
# <ipython-input-92-fc98b9edbc77> in <genexpr>(.0)
# ...

# %% [markdown]
# К сожалению, моих знаний классического Python не хватает для выполнения этого задания.
